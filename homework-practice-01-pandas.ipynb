# %% [markdown]
# # Домашнее задание 1 - PANDAS

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В каждом разделе вам предлагается выполнить несколько заданий. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотекам pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написаем production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.
#
# ### Формат сдачи
# Для сдачи задания получившийся файл \*.ipynb с решением необходимо выложить в свой репозиторий github.

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных. С этой библиотекой мы сейчас и познакомимся.
#
# Основной объект в pandas это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
# import almost all we need
import numpy as np
import pandas as pd
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Kasyanoff\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\magics\pylab.py:162: UserWarning: pylab import has clobbered these variables: ['bar']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# Данные находятся в приложенном файле `chipotle.tsv`

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы?

# %%
cp = pd.read_csv('chipotle.tsv', sep='\t')
cp.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %% [markdown]
# #### 2. [0.25 баллов] Ответьте на вопросы:
# 1. Сколько заказов попало в выборку?
# 2. Сколько уникальных категорий товара было куплено? (item_name)

# %%
cp.dropna(axis=1)
# Out:
#       order_id  quantity                              item_name item_price
# 0            1         1           Chips and Fresh Tomato Salsa     $2.39
# 1            1         1                                   Izze     $3.39
# 2            1         1                       Nantucket Nectar     $3.39
# 3            1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2         2                           Chicken Bowl    $16.98
# ...        ...       ...                                    ...        ...
# 4617      1833         1                          Steak Burrito    $11.75
# 4618      1833         1                          Steak Burrito    $11.75
# 4619      1834         1                     Chicken Salad Bowl    $11.25
# 4620      1834         1                     Chicken Salad Bowl     $8.75
# 4621      1834         1                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 4 columns]

# %%
cp.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
unique_category = len(set(cp['item_name']))
print(unique_category)
# Out:
# 50

# %% [markdown]
# **Ответ:**
# 1. *1834 заказа (order_id)*
# 2. *50 уникальных категорий*

# %% [markdown]
# #### 3. [0.25 баллов] Есть ли в данных пропуски? В каких колонках?

# %%
print(cp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# None

# %% [markdown]
# **Ответ:** *Пропуски содержаться в колонке **choice_description**.*

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
cp = cp.fillna(value='')
cp
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                           $2.39
# ...

# %% [markdown]
# #### 4. [0.5 баллов] Посмотрите внимательнее на колонку с ценой товара. Какого она типа? Создайте новую колонку так, чтобы в ней цена была числом.
#
# Для этого попробуйте применить функцию-преобразование к каждой строке вашей таблицы (для этого есть соответствующая функция).

# %% [markdown]
# *Колонка **item_price** имеет тип `object`.*

# %%
cp['Price'] = cp['item_price'].apply(lambda x: float(x[1:]))
cp
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  Price
# 0                                                           $2.39    2.39
# ...

# %% [markdown]
# Какая средняя/минимальная/максимальная цена у товара?

# %% [markdown]
# *Как я понимаю, речь идёт об одной единице товара*.

# %%
agr = cp.copy()
agr['Price'] = agr['Price'] / agr['quantity']
agr['Price'].describe()
# Out:
# count    4622.000000
# mean        7.084424
# std         3.665487
# min         1.090000
# 25%         2.950000
# 50%         8.750000
# 75%         9.250000
# max        11.890000
# Name: Price, dtype: float64

# %% [markdown]
# **Ответ:**
# * Средняя цена - 7,08;
# * минимальная - 1,09;
# * максимальная - 11,89.

# %% [markdown]
# Удалите старую колонку с ценой.

# %%
cp.pop('item_price')
cp
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  Price
# 0                                                         2.39
# 1                                          [Clementine]   3.39
# ...

# %% [markdown]
# #### 5. [0.25 баллов] Какие 5 товаров были самыми дешёвыми и самыми дорогими? (по item_name)
#
# Для этого будет удобно избавиться от дубликатов и отсортировать товары. Не забудьте про количество товара.

# %%
lux = cp.copy()  # Создаём копию 
lux['Price'] = lux['Price'] / lux['quantity']  # Цена за 1 товар
lux.pop('quantity')  # Теперь этот столбец нам не нужен (он даже может нам помешать)
lux = lux.drop_duplicates(subset=['item_name'])  # Избавляемся от повторяющихся строк
lux = lux.sort_values(by=['Price'])  # Отсортируем по цене

# %% [markdown]
# *5 самых дешёвых товаров:*

# %%
lux.head(5)
# Out:
#      order_id          item_name choice_description  Price
# 34         17      Bottled Water                      1.09
# 18          9        Canned Soda           [Sprite]   1.09
# 263       114  Canned Soft Drink             [Coke]   1.25
# 6           3      Side of Chips                      1.69
# 40         19              Chips                      2.15

# %% [markdown]
# *5 самых дорогих товаров:*

# %%
lux.tail(5)
# Out:
#       order_id              item_name  \
# 7            4          Steak Burrito
# 168         75  Barbacoa Crispy Tacos
# 1132       468    Carnitas Salad Bowl
# 1229       501    Barbacoa Salad Bowl
# 281        123       Steak Salad Bowl
#
#                                      choice_description  Price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...  11.75
# 168   [Tomatillo Red Chili Salsa, [Rice, Black Beans...  11.75
# 1132  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  11.89
# 1229  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...  11.89
# 281   [Tomatillo Red Chili Salsa, [Black Beans, Chee...  11.89

# %% [markdown]
# #### 6. [0.5 баллов] Сколько раз клиенты покупали больше 1 Chicken Bowl (item_name)?

# %%
cp[(cp['item_name'] == 'Chicken Bowl') & (cp['quantity'] > 1)]['order_id'].count()
# Out:
# 33

# %% [markdown]
# **Ответ:** *33 раза.*

# %% [markdown]
# #### 7. [0.5 баллов] Какой средний чек у заказа? Сколько в среднем товаров покупают?
#
# Если необходимо провести вычисления в терминах заказов, то будет удобно сгруппировать строки по заказам и посчитать необходимые статистики.

# %% [markdown]
# *Произвёл группировку по id заказа, нашёл количество позиций в заказе и его стоимость.*

# %%
check = cp.iloc[:, [0, 1, 4]]
check = check.groupby('order_id').sum()
check
# Out:
#           quantity  Price
# order_id
# 1                4  11.56
# 2                2  16.98
# 3                2  12.67
# 4                2  21.00
# 5                2  13.70
# ...            ...    ...
# 1830             2  23.00
# 1831             3  12.90
# 1832             2  13.20
# 1833             2  23.50
# 1834             3  28.75
#
# [1834 rows x 2 columns]

# %% [markdown]
# *Теперь легко посчитать средний чек и среднее число позиций в заказе.*

# %%
check.mean()
# Out:
# quantity     2.711014
# Price       18.811429
# dtype: float64

# %% [markdown]
# **Ответ:**
# * *Средний чек: 18,81*
# * *Среднее число позиций: 2,71 ~ 3*

# %% [markdown]
# #### 8. [0.25 баллов] Сколько заказов содержали ровно 1 товар?

# %%
check[check['quantity'] == 1].quantity.count()
# Out:
# 56

# %% [markdown]
# **Ответ:** *56 заказов*

# %% [markdown]
# #### 9. [0.25 баллов] Какая самая популярная категория товара?

# %%
popular = cp.iloc[:, [2, 1]]
popular = popular.groupby('item_name').sum()
popular.sort_values(by=['quantity']).tail(1)
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# #### 10. [0.5 баллов] Какие виды Burrito существуют? Какой из них чаще всего покупают? Какой из них самый дорогой?

# %% [markdown]
# *Вывожу заказы буррито.*

# %%
burrito = cp.copy()
burrito = burrito[burrito.item_name.str.contains('Burrito')].iloc[:, [2, 1, 4]]
burrito
# Out:
#              item_name  quantity  Price
# 7        Steak Burrito         1  11.75
# 9        Steak Burrito         1   9.25
# 16     Chicken Burrito         1   8.49
# 17     Chicken Burrito         1   8.49
# 21    Barbacoa Burrito         1   8.99
# ...                ...       ...    ...
# 4608    Veggie Burrito         1  11.25
# 4610     Steak Burrito         1  11.75
# 4611    Veggie Burrito         1  11.25
# 4617     Steak Burrito         1  11.75
# 4618     Steak Burrito         1  11.75
#
# [1172 rows x 3 columns]

# %% [markdown]
# *Дело за малым - выполняю группировку и агрегацию.*

# %%
burrito.groupby('item_name').sum()
# Out:
#                   quantity    Price
# item_name
# Barbacoa Burrito        91   894.75
# Burrito                  6    44.40
# Carnitas Burrito        60   597.83
# Chicken Burrito        591  5575.82
# Steak Burrito          386  3851.43
# Veggie Burrito          97   934.77

# %% [markdown]
# *Существует **6 видов** буррито. Самым популярным является **Chicken Burrito**.*
#
# *Теперь выясним, какой заказ был самым дорогим.*

# %%
burrito['Price'] = burrito['Price'] / burrito['quantity']
burrito.pop('quantity')
burrito = burrito.drop_duplicates(subset=['item_name'])
burrito = burrito.sort_values(by=['Price'])
burrito
# Out:
#             item_name  Price
# 510           Burrito   7.40
# 16    Chicken Burrito   8.49
# 21   Barbacoa Burrito   8.99
# 27   Carnitas Burrito   8.99
# 57     Veggie Burrito  11.25
# 7       Steak Burrito  11.75

# %% [markdown]
# *Самымый дорогой буррито - **Steak Burrito** за **11,75**.*

# %% [markdown]
# #### 11. [0.75 баллов] В каком количестве заказов есть товар, который стоит более 40% от суммы всего чека?
#
# Возможно, будет удобно посчитать отдельно ~~среднюю~~ стоимость заказа, добавить ее в исходные данные и сделать необходимые проверки.
#
# *Данный комментарий стоит воспринимать как подсказку к одному из вариантов решений задания. Если в вашем варианте решения он не нужнен, это не страшно*

# %% [markdown]
# **Первая мысля:** Добавить колонку со стоимостью всего заказа. Я вижу тут один путь - надо заджойнить, ибо не зря ж я эту фигню знаю.

# %%
stats = cp.iloc[:, [0, 4]]
stats = stats.groupby('order_id').sum()
stats.rename(columns={'Price':'Total'}, inplace=True)
stats
# Out:
#           Total
# order_id
# 1         11.56
# 2         16.98
# 3         12.67
# 4         21.00
# 5         13.70
# ...         ...
# 1830      23.00
# 1831      12.90
# 1832      13.20
# 1833      23.50
# 1834      28.75
#
# [1834 rows x 1 columns]

# %% [markdown]
# Присоединяю к таблице колонку **Total**.

# %%
heavy = cp.copy()
heavy = pd.merge(heavy, stats, on="order_id")
heavy.pop('choice_description')
heavy
# Out:
#       order_id  quantity                              item_name  Price  Total
# 0            1         1           Chips and Fresh Tomato Salsa   2.39  11.56
# 1            1         1                                   Izze   3.39  11.56
# 2            1         1                       Nantucket Nectar   3.39  11.56
# 3            1         1  Chips and Tomatillo-Green Chili Salsa   2.39  11.56
# 4            2         2                           Chicken Bowl  16.98  16.98
# ...        ...       ...                                    ...    ...    ...
# 4617      1833         1                          Steak Burrito  11.75  23.50
# 4618      1833         1                          Steak Burrito  11.75  23.50
# 4619      1834         1                     Chicken Salad Bowl  11.25  28.75
# 4620      1834         1                     Chicken Salad Bowl   8.75  28.75
# 4621      1834         1                     Chicken Salad Bowl   8.75  28.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# Заджойнил, всё Чикаго.  В условии задачи, скорее всего, имеется ввиду цена одной единицы товара. Что делать дальше - ежу понятно.
#
# **Для тех, кто не ёж**: делю стоимость на количество. От количества избавляюсь. Получу цену товара, фигурирующего в заказе.

# %%
heavy['Price'] = heavy['Price'] / heavy['quantity']
heavy.pop('quantity')
heavy
# Out:
#       order_id                              item_name  Price  Total
# 0            1           Chips and Fresh Tomato Salsa   2.39  11.56
# 1            1                                   Izze   3.39  11.56
# 2            1                       Nantucket Nectar   3.39  11.56
# 3            1  Chips and Tomatillo-Green Chili Salsa   2.39  11.56
# 4            2                           Chicken Bowl   8.49  16.98
# ...        ...                                    ...    ...    ...
# 4617      1833                          Steak Burrito  11.75  23.50
# 4618      1833                          Steak Burrito  11.75  23.50
# 4619      1834                     Chicken Salad Bowl  11.25  28.75
# 4620      1834                     Chicken Salad Bowl   8.75  28.75
# 4621      1834                     Chicken Salad Bowl   8.75  28.75
#
# [4622 rows x 4 columns]

# %% [markdown]
# Вывожу те товары, **цена** которых больше, чем 40% от чека заказа. Затем просто посчитаю количество заказов.

# %%
heavy = heavy[heavy['Price'] > 0.4 * heavy['Total']]
unique_id = len(set(heavy['order_id']))
print(unique_id)
# Out:
# 1589

# %%
heavy.groupby('order_id').sum()
# Out:
#                                        item_name  Price  Total
# order_id
# 2                                   Chicken Bowl   8.49  16.98
# 3                                   Chicken Bowl  10.98  12.67
# 4                  Steak BurritoSteak Soft Tacos  21.00  42.00
# 5                                  Steak Burrito   9.25  13.70
# 6         Chicken Crispy TacosChicken Soft Tacos  17.50  35.00
# ...                                          ...    ...    ...
# 1829                 Steak BurritoVeggie Burrito  23.00  48.50
# 1830                 Steak BurritoVeggie Burrito  23.00  46.00
# 1831                               Carnitas Bowl   9.25  12.90
# 1832                          Chicken Soft Tacos   8.75  13.20
# 1833                  Steak BurritoSteak Burrito  23.50  47.00
#
# [1589 rows x 3 columns]

# %% [markdown]
# **Ответ:** *1589 заказов.*

# %% [markdown]
# #### 12. [0.75 баллов] Предположим, что в данных была ошибка и Diet Coke (choice_description), который стоил $1.25, должен был стоить 1.35. Скорректируйте данные в таблице и посчитайте, на какой процент больше денег было заработано с этого товара. Не забывайте, что количество товара не всегда равно 1.

# %%
coke = cp[cp.choice_description.str.contains('Diet Coke')]
coke = coke[coke['Price'] == 1.25]
coke
# Out:
#       order_id  quantity          item_name choice_description  Price
# 368        159         1  Canned Soft Drink        [Diet Coke]   1.25
# 513        215         1  Canned Soft Drink        [Diet Coke]   1.25
# 541        225         1  Canned Soft Drink        [Diet Coke]   1.25
# 566        233         1  Canned Soft Drink        [Diet Coke]   1.25
# 567        233         1  Canned Soft Drink        [Diet Coke]   1.25
# ...        ...       ...                ...                ...    ...
# 4513      1794         1  Canned Soft Drink        [Diet Coke]   1.25
# 4545      1806         1  Canned Soft Drink        [Diet Coke]   1.25
# 4571      1817         1  Canned Soft Drink        [Diet Coke]   1.25
# 4585      1823         1  Canned Soft Drink        [Diet Coke]   1.25
# 4601      1827         1  Canned Soft Drink        [Diet Coke]   1.25
#
# [79 rows x 5 columns]

# %% [markdown]
# По всей видимости, количество товара **всегда** равно единице :)

# %%
coke['quantity'].sum()
# Out:
# 79

# %% [markdown]
# Время вспомнить математику уровня детского сада. Мне достаточно узнать, на сколько процентов изменилась цена лишь одного товара $-$ цены товаров одинаковые, прирост прибыли в процентах совпадает с ростом цены одного товара.
#
# $$\frac{1,35 - 1,25}{1,25} \cdot 100\% = \frac{0,1}{1,25} \cdot 100\% = \frac{10}{125} \cdot 100\% = \frac{10}{5} \cdot 4\% = 8 \%$$
#
# <p style="text-align: center;">Было заработано больше на 8%</p>

# %%
cp.loc[(cp['order_id'].isin(coke['order_id'])) & (cp['choice_description'] == '[Diet Coke]') & (cp['Price'] == 1.25), 'Price'] = 1.35
cp[(cp['order_id'].isin(coke['order_id'])) & (cp['choice_description'] == '[Diet Coke]') & (cp['Price'] == 1.25)]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, Price]
# Index: []

# %%
cp[(cp['order_id'].isin(coke['order_id'])) & (cp['choice_description'] == '[Diet Coke]') & (cp['Price'] == 1.35)]
# Out:
#       order_id  quantity          item_name choice_description  Price
# 368        159         1  Canned Soft Drink        [Diet Coke]   1.35
# 513        215         1  Canned Soft Drink        [Diet Coke]   1.35
# 541        225         1  Canned Soft Drink        [Diet Coke]   1.35
# 566        233         1  Canned Soft Drink        [Diet Coke]   1.35
# 567        233         1  Canned Soft Drink        [Diet Coke]   1.35
# ...        ...       ...                ...                ...    ...
# 4513      1794         1  Canned Soft Drink        [Diet Coke]   1.35
# 4545      1806         1  Canned Soft Drink        [Diet Coke]   1.35
# 4571      1817         1  Canned Soft Drink        [Diet Coke]   1.35
# 4585      1823         1  Canned Soft Drink        [Diet Coke]   1.35
# 4601      1827         1  Canned Soft Drink        [Diet Coke]   1.35
#
# [79 rows x 5 columns]

# %% [markdown]
# Всё заменил.

# %% [markdown]
# #### 13. [0.75 баллов] Создайте новый DateFrame из матрицы, созданной ниже. Назовите колонки index, column1, column2 и сделайте первую колонку индексом.

# %% [markdown]
# О_о не понял задачу. Объясните $-$ сделаю :33

# %% [markdown]
# Сохраните DataFrame на диск в формате csv без индексов и названий столбцов.

# %%
# your code

# %% [markdown]
# ## 2. Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. В этом разделе мы этим и займёмся.
#
# У matplotlib, конечно, же есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторое величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить каждый из них. Не менее важно усвоить базовые принципы визуализаций:
# - на графиках должны быть подписаны оси;
# - у визуализации должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах).
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать.

# %%
# %matplotlib inline  
#нужно для отображения графиков внутри ноутбука
import matplotlib.pyplot as plt

# %% [markdown]
# На самом деле мы уже импортировали matplotlib внутри %pylab inline в начале задания.
#
# Работать мы будем с той же выборкой покупкок. Добавим новую колонку с датой покупки.

# %%
import datetime

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 1, 31)
delta_seconds = int((end - start).total_seconds())

dates = pd.DataFrame(index=cp.order_id.unique())
dates['date'] = [
    (start + datetime.timedelta(seconds=random.randint(0, delta_seconds))).strftime('%Y-%m-%d')
    for _ in range(cp.order_id.nunique())]

# если DataFrame с покупками из прошлого заказа называется не df, замените на ваше название ниже
cp['date'] = cp.order_id.map(dates['date'])
cp
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  Price        date
# 0                                                         2.39  2018-01-03
# ...

# %% [markdown]
# #### 1. [1 балл] Постройте гистограмму распределения сумм покупок и гистограмму средних цен отдельных видов продуктов item_name.
#
# Изображайте на двух соседних графиках. Для этого может быть полезен subplot.

# %% [markdown]
# #### 2. [1 балл] Постройте график зависимости суммы покупок от дней.

# %%
# Сумма покупок за каждый день
graph = cp.iloc[:, [-1, -2]].groupby('date').sum()

# %%
graph = np.array(graph['Price'])
graph
# Out:
# array([1197.92, 1314.89,  995.6 , 1401.42, 1236.77, 1063.28,  944.53,
#         896.27, 1109.81, 1126.73, 1374.72,  708.1 , 1064.92, 1101.61,
#         885.11, 1019.45, 1401.11, 1220.01, 1249.94,  999.54, 1270.47,
#        1224.85, 1092.11, 1226.03, 1220.12, 1451.07, 1275.71,  952.33,
#        1315.84, 1167.8 ])

# %%
days = np.arange(1, 31, 1)
fig = plt.figure(figsize=(12, 5))
ax = plt.subplot(1, 1, 1)

ax.plot(days, graph, '--o', color='#ffa8af', markerfacecolor='w')
plt.xticks(np.arange(1, 31, 1))
plt.xlabel("День")
plt.ylabel("Сумма покупок за день")
ax.grid()
plt.show()

# %% [markdown]
# #### 3. [1 балл] Постройте средних сумм покупок по дням недели (bar plot).

# %%
bar = cp.copy().iloc[:, [-1, -2]]

bar['day'] = bar['date'].apply(lambda x: int(x[-2:]) % 7)
bar.pop('date')
bar.loc[bar['day'] == 0] = 7
bar = bar.groupby('day').sum()
bar
# Out:
#        Price
# day
# 1    6003.61
# 2    5298.26
# 3    5245.14
# 4    4596.69
# 5    4594.59
# 6    4507.88
# 7    3990.00

# %%
days = ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс']

fig, ax = plt.subplots()

ax.bar(days, bar['Price'])

ax.set_ylabel('Сумма покупок')
ax.set_title('Суммы покупок по дням недели')

plt.show()

# %% [markdown]
# #### 4. [1 балл] Постройте график зависимости денег за товар от купленного количества (scatter plot).

# %%
# your code

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# Ссылки на источники:
#
# https://numpy.org/devdocs/user/absolute_beginners.html#how-to-create-an-array-from-existing-data
#
# https://matplotlib.org/stable/users/explain/quick_start.html
#
# https://tonais.ru/library/dobavlenie-i-udalenie-stolbtsa-v-dataframe#:~:text=Чтобы%20удалить%20или%20удалить%20только,Pandas%2C%20используйте%20функцию%20drop%20()
